# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv(r"D:\ICT Academy\virtual competition\test.csv")
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
data.shape
# Out:
# (5681, 11)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The preprocessing done here is similar to that we have done on our training data set

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data['Item_Identifier'].nunique()
# Out:
# 1543

# %%
data['Item_Identifier'].unique()
# Out:
# array(['FDW58', 'FDW14', 'NCN55', ..., 'NCI29', 'FDP28', 'FDF04'],
#       dtype=object)

# %%
item_id=data['Item_Identifier'].unique()

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
data[data['Item_Identifier']=='FDW58']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58        20.75          Low Fat         0.007565
# 253            FDW58        20.75          Low Fat         0.007596
# 1625           FDW58        20.75          Low Fat         0.007584
# 1892           FDW58        20.75          Low Fat         0.000000
# 2166           FDW58        20.75          Low Fat         0.007568
# 2434           FDW58          NaN          Low Fat         0.007517
# 2830           FDW58          NaN          Low Fat         0.013224
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0     Snack Foods  107.8622            OUT049                       1999
# 253   Snack Foods  104.4622            OUT017                       2007
# 1625  Snack Foods  107.0622            OUT018                       2009
# 1892  Snack Foods  105.9622            OUT046                       1997
# 2166  Snack Foods  105.8622            OUT045                       2002
# 2434  Snack Foods  107.6622            OUT027                       1985
# 2830  Snack Foods  106.4622            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 0         Medium               Tier 1  Supermarket Type1
# 253          NaN               Tier 2  Supermarket Type1
# 1625      Medium               Tier 3  Supermarket Type2
# 1892       Small               Tier 1  Supermarket Type1
# 2166         NaN               Tier 2  Supermarket Type1
# 2434      Medium               Tier 3  Supermarket Type3
# 2830       Small               Tier 1      Grocery Store

# %%
item_id
# Out:
# array(['FDW58', 'FDW14', 'NCN55', ..., 'NCI29', 'FDP28', 'FDF04'],
#       dtype=object)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
fm=[]
data1=pd.DataFrame(columns=['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility','Item_Type', 'Item_MRP', 'Outlet_Identifier','Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type','Outlet_Type'])
for i in item_id:
    dataframe=data[data['Item_Identifier']==i]
    dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
    fm.append(dataframe)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Python\lib\site-packages\numpy\lib\nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# ...
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Python\lib\site-packages\numpy\lib\nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Python\lib\site-packages\numpy\lib\nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Python\lib\site-packages\numpy\lib\nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())
# C:\Python\lib\site-packages\numpy\lib\nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\14926070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Item_Weight']=dataframe['Item_Weight'].fillna(dataframe['Item_Weight'].median())

# %%
data1=pd.concat(fm)

# %%
data1['Item_Identifier'].nunique()
# Out:
# 1543

# %%
data1.shape
# Out:
# (5681, 11)

# %%
data1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                    20
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data1[data1['Item_Identifier']=='NCN55']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 2              NCN55         14.6          Low Fat         0.099575    Others
# 1906           NCN55         14.6          Low Fat         0.059202    Others
# 2978           NCN55         14.6          Low Fat         0.059491    Others
# 5194           NCN55         14.6          Low Fat         0.059441    Others
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 2     241.7538            OUT010                       1998         NaN
# 1906  239.3538            OUT027                       1985      Medium
# 2978  241.4538            OUT046                       1997       Small
# 5194  239.4538            OUT013                       1987        High
#
#      Outlet_Location_Type        Outlet_Type
# 2                  Tier 3      Grocery Store
# 1906               Tier 3  Supermarket Type3
# 2978               Tier 1  Supermarket Type1
# 5194               Tier 3  Supermarket Type1

# %% [markdown]
# Data 1

# %%
plt.hist(data1['Item_Weight'])
plt.show()

# %%
#we can fill the next vacent place with median value

# %%
for cols in ['Item_Weight']:
    data1[cols]=data1[cols].fillna(data1[cols].median())
data1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data1['Item_Weight'].median()
# Out:
# 12.35

# %%
#Item_Fat_Content

# %%
data1['Item_Fat_Content'].nunique()
# Out:
# 5

# %%
data1['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'reg', 'Regular', 'LF', 'low fat'], dtype=object)

# %%
data1.loc[(data1['Item_Fat_Content']=='LF') | (data1['Item_Fat_Content']=='low fat'),'Item_Fat_Content']='Low Fat'
data1.loc[(data1['Item_Fat_Content']=='reg'),'Item_Fat_Content']='Regular'

# %%
data1['Item_Fat_Content'].nunique()
# Out:
# 2

# %%
data1['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
#Item_Visibility

# %%
plt.boxplot(data['Item_Visibility'])
plt.show()

# %%
data1['Item_Visibility'].nunique()
# Out:
# 5277

# %%
data1.head(3)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58        20.75          Low Fat         0.007565
# 253            FDW58        20.75          Low Fat         0.007596
# 1625           FDW58        20.75          Low Fat         0.007584
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0     Snack Foods  107.8622            OUT049                       1999
# 253   Snack Foods  104.4622            OUT017                       2007
# 1625  Snack Foods  107.0622            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 0         Medium               Tier 1  Supermarket Type1
# 253          NaN               Tier 2  Supermarket Type1
# 1625      Medium               Tier 3  Supermarket Type2

# %%
data1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#item type

# %%
data1['Item_Type'].nunique()
# Out:
# 16

# %%
data1['Item_Type'].unique()
# Out:
# array(['Snack Foods', 'Dairy', 'Others', 'Fruits and Vegetables',
#        'Baking Goods', 'Health and Hygiene', 'Breads', 'Hard Drinks',
#        'Seafood', 'Soft Drinks', 'Household', 'Frozen Foods', 'Meat',
#        'Canned', 'Starchy Foods', 'Breakfast'], dtype=object)

# %%
itemtype=data1['Item_Type'].unique()

# %%
#Outlet_Identifier

# %%
data1['Outlet_Identifier'].nunique()
# Out:
# 10

# %%
data1['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT017', 'OUT018', 'OUT046', 'OUT045', 'OUT027',
#        'OUT019', 'OUT010', 'OUT013', 'OUT035'], dtype=object)

# %%
outlietid=data1['Outlet_Identifier'].unique()

# %%
#Outlet_Size

# %%
data1['Outlet_Size'].nunique()
# Out:
# 3

# %%
data1['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'Small', 'High'], dtype=object)

# %%
data1.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58        20.75          Low Fat         0.007565
# 253            FDW58        20.75          Low Fat         0.007596
# 1625           FDW58        20.75          Low Fat         0.007584
# 1892           FDW58        20.75          Low Fat         0.000000
# 2166           FDW58        20.75          Low Fat         0.007568
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0     Snack Foods  107.8622            OUT049                       1999
# 253   Snack Foods  104.4622            OUT017                       2007
# 1625  Snack Foods  107.0622            OUT018                       2009
# 1892  Snack Foods  105.9622            OUT046                       1997
# 2166  Snack Foods  105.8622            OUT045                       2002
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 0         Medium               Tier 1  Supermarket Type1
# 253          NaN               Tier 2  Supermarket Type1
# 1625      Medium               Tier 3  Supermarket Type2
# 1892       Small               Tier 1  Supermarket Type1
# 2166         NaN               Tier 2  Supermarket Type1

# %%
data1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data_1=pd.DataFrame(columns=['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility','Item_Type', 'Item_MRP', 'Outlet_Identifier','Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type','Outlet_Type', 'Item_Outlet_Sales'])

# %%
df_1=[]
for i in itemtype:
    dataframe_1=data1[data1['Item_Type']==i]
    modevalue=dataframe_1['Outlet_Size'].mode()
    dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
    df_1.append(dataframe_1)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3934383828.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1['Outlet_Size']=dataframe_1['Outlet_Size'].fillna(modevalue[0])

# %%
data_1=pd.concat(df_1)

# %%
data_1.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58        20.75          Low Fat         0.007565
# 253            FDW58        20.75          Low Fat         0.007596
# 1625           FDW58        20.75          Low Fat         0.007584
# 1892           FDW58        20.75          Low Fat         0.000000
# 2166           FDW58        20.75          Low Fat         0.007568
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0     Snack Foods  107.8622            OUT049                       1999
# 253   Snack Foods  104.4622            OUT017                       2007
# 1625  Snack Foods  107.0622            OUT018                       2009
# 1892  Snack Foods  105.9622            OUT046                       1997
# 2166  Snack Foods  105.8622            OUT045                       2002
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 0         Medium               Tier 1  Supermarket Type1
# 253       Medium               Tier 2  Supermarket Type1
# 1625      Medium               Tier 3  Supermarket Type2
# 1892       Small               Tier 1  Supermarket Type1
# 2166      Medium               Tier 2  Supermarket Type1

# %%
data_1.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
data1[data1['Outlet_Identifier']=='OUT017']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 253            FDW58       20.750          Low Fat         0.007596
# 1              FDW14        8.300          Regular         0.038428
# 3              FDQ58        7.315          Low Fat         0.015388
# 4370           FDH56        9.800          Regular         0.064178
# 4970           FDN33        6.305          Regular         0.123812
# ...              ...          ...              ...              ...
# 5250           FDB40       17.500          Regular         0.007583
# 5020           FDI60        7.220          Regular         0.038538
# 5421           FDX34        6.195          Low Fat         0.072393
# 5241           FDQ39       14.800          Low Fat         0.081501
# 5272           FDU12       15.500          Regular         0.076180
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 253             Snack Foods  104.4622            OUT017
# 1                     Dairy   87.3198            OUT017
# 3               Snack Foods  155.0340            OUT017
# 4370  Fruits and Vegetables  115.7492            OUT017
# 4970            Snack Foods   96.3436            OUT017
# ...                     ...       ...               ...
# 5250                  Dairy  145.5102            OUT017
# 5020           Baking Goods   64.9510            OUT017
# 5421            Snack Foods  122.2098            OUT017
# 5241                   Meat  192.2846            OUT017
# 5272           Baking Goods  263.1568            OUT017
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 253                        2007         NaN               Tier 2
# 1                          2007         NaN               Tier 2
# 3                          2007         NaN               Tier 2
# 4370                       2007         NaN               Tier 2
# 4970                       2007         NaN               Tier 2
# ...                         ...         ...                  ...
# 5250                       2007         NaN               Tier 2
# 5020                       2007         NaN               Tier 2
# 5421                       2007         NaN               Tier 2
# 5241                       2007         NaN               Tier 2
# 5272                       2007         NaN               Tier 2
#
#             Outlet_Type
# 253   Supermarket Type1
# 1     Supermarket Type1
# 3     Supermarket Type1
# 4370  Supermarket Type1
# 4970  Supermarket Type1
# ...                 ...
# 5250  Supermarket Type1
# 5020  Supermarket Type1
# 5421  Supermarket Type1
# 5241  Supermarket Type1
# 5272  Supermarket Type1
#
# [617 rows x 11 columns]

# %%
dddf=data_1[data_1['Outlet_Identifier']=='OUT019']
dddf['Outlet_Identifier'].nunique()
# Out:
# 1

# %%
data2=pd.DataFrame(columns=['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility','Item_Type', 'Item_MRP', 'Outlet_Identifier','Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type','Outlet_Type'])
df2=[]
for i in outlietid:
    dataframe2=data_1[data_1['Outlet_Identifier']==i]
    modevalue=dataframe2['Outlet_Size'].mode()
    dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
    df2.append(dataframe2)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])
# C:\Users\chris\AppData\Local\Temp\ipykernel_14028\3841433393.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe2['Outlet_Size']=dataframe2['Outlet_Size'].fillna(modevalue[0])

# %%
data2=pd.concat(df2)

# %%
data2.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 3578           FDS10       19.200          Low Fat         0.035240
# 1840           FDX22        6.785          Regular         0.023011
# 4606           FDV21       11.500          Low Fat         0.171349
# 380            FDW21        5.340          Regular         0.005973
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0     Snack Foods  107.8622            OUT049                       1999
# 3578  Snack Foods  178.7318            OUT049                       1999
# 1840  Snack Foods  209.1928            OUT049                       1999
# 4606  Snack Foods  125.7704            OUT049                       1999
# 380   Snack Foods   99.0358            OUT049                       1999
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 0         Medium               Tier 1  Supermarket Type1
# 3578      Medium               Tier 1  Supermarket Type1
# 1840      Medium               Tier 1  Supermarket Type1
# 4606      Medium               Tier 1  Supermarket Type1
# 380       Medium               Tier 1  Supermarket Type1

# %% [markdown]
# data 2

# %%
data2['Outlet_Size'].unique()
# Out:
# array(['Medium', 'Small', 'High'], dtype=object)

# %%
data2.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
data2['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 2', 'Tier 3'], dtype=object)

# %%
data2['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Supermarket Type3',
#        'Grocery Store'], dtype=object)

# %%
data3=data2

# %%
data3.head(3)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 3578           FDS10       19.200          Low Fat         0.035240
# 1840           FDX22        6.785          Regular         0.023011
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0     Snack Foods  107.8622            OUT049                       1999
# 3578  Snack Foods  178.7318            OUT049                       1999
# 1840  Snack Foods  209.1928            OUT049                       1999
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 0         Medium               Tier 1  Supermarket Type1
# 3578      Medium               Tier 1  Supermarket Type1
# 1840      Medium               Tier 1  Supermarket Type1

# %% [markdown]
# data 3

# %%
#we can make use of data3 for the rest preprocessing

# %%
corrmatrix=data3.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=-0.1, vmax=0.9, annot=True)
# Out:
# <AxesSubplot:>

# %%
data3.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
data4=data3.drop(['Item_Visibility','Outlet_Establishment_Year'],axis=1)

# %% [markdown]
# data4 is the data after droping

# %%
data4.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
data4['Item_Fat_Content']=LE.fit_transform(data4['Item_Fat_Content'])
data4.head()
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content    Item_Type  Item_MRP  \
# 0              FDW58       20.750                 0  Snack Foods  107.8622
# 3578           FDS10       19.200                 0  Snack Foods  178.7318
# 1840           FDX22        6.785                 1  Snack Foods  209.1928
# 4606           FDV21       11.500                 0  Snack Foods  125.7704
# 380            FDW21        5.340                 1  Snack Foods   99.0358
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 3578            OUT049      Medium               Tier 1  Supermarket Type1
# 1840            OUT049      Medium               Tier 1  Supermarket Type1
# 4606            OUT049      Medium               Tier 1  Supermarket Type1
# 380             OUT049      Medium               Tier 1  Supermarket Type1

# %%
data4['Item_Type']=LE.fit_transform(data4['Item_Type'])
data4.head()
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  \
# 0              FDW58       20.750                 0         13  107.8622
# 3578           FDS10       19.200                 0         13  178.7318
# 1840           FDX22        6.785                 1         13  209.1928
# 4606           FDV21       11.500                 0         13  125.7704
# 380            FDW21        5.340                 1         13   99.0358
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 3578            OUT049      Medium               Tier 1  Supermarket Type1
# 1840            OUT049      Medium               Tier 1  Supermarket Type1
# 4606            OUT049      Medium               Tier 1  Supermarket Type1
# 380             OUT049      Medium               Tier 1  Supermarket Type1

# %%
data4['Outlet_Location_Type']=LE.fit_transform(data4['Outlet_Location_Type'])
data4.head()
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  \
# 0              FDW58       20.750                 0         13  107.8622
# 3578           FDS10       19.200                 0         13  178.7318
# 1840           FDX22        6.785                 1         13  209.1928
# 4606           FDV21       11.500                 0         13  125.7704
# 380            FDW21        5.340                 1         13   99.0358
#
#      Outlet_Identifier Outlet_Size  Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium                     0  Supermarket Type1
# 3578            OUT049      Medium                     0  Supermarket Type1
# 1840            OUT049      Medium                     0  Supermarket Type1
# 4606            OUT049      Medium                     0  Supermarket Type1
# 380             OUT049      Medium                     0  Supermarket Type1

# %%
data4['Outlet_Type']=LE.fit_transform(data4['Outlet_Type'])
data4.head()
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  \
# 0              FDW58       20.750                 0         13  107.8622
# 3578           FDS10       19.200                 0         13  178.7318
# 1840           FDX22        6.785                 1         13  209.1928
# 4606           FDV21       11.500                 0         13  125.7704
# 380            FDW21        5.340                 1         13   99.0358
#
#      Outlet_Identifier Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               OUT049      Medium                     0            1
# 3578            OUT049      Medium                     0            1
# 1840            OUT049      Medium                     0            1
# 4606            OUT049      Medium                     0            1
# 380             OUT049      Medium                     0            1

# %%
data4['Outlet_Size']=LE.fit_transform(data4['Outlet_Size'])
data4.head()
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  \
# 0              FDW58       20.750                 0         13  107.8622
# 3578           FDS10       19.200                 0         13  178.7318
# 1840           FDX22        6.785                 1         13  209.1928
# 4606           FDV21       11.500                 0         13  125.7704
# 380            FDW21        5.340                 1         13   99.0358
#
#      Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               OUT049            1                     0            1
# 3578            OUT049            1                     0            1
# 1840            OUT049            1                     0            1
# 4606            OUT049            1                     0            1
# 380             OUT049            1                     0            1

# %%
data4['Outlet_Identifier']=LE.fit_transform(data4['Outlet_Identifier'])
data4.head()
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  \
# 0              FDW58       20.750                 0         13  107.8622
# 3578           FDS10       19.200                 0         13  178.7318
# 1840           FDX22        6.785                 1         13  209.1928
# 4606           FDV21       11.500                 0         13  125.7704
# 380            FDW21        5.340                 1         13   99.0358
#
#       Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                     9            1                     0            1
# 3578                  9            1                     0            1
# 1840                  9            1                     0            1
# 4606                  9            1                     0            1
# 380                   9            1                     0            1

# %%
LE.inverse_transform(data4['Outlet_Identifier'])
# Out:
# array(['OUT049', 'OUT049', 'OUT049', ..., 'OUT035', 'OUT035', 'OUT035'],
#       dtype=object)

# %% [markdown]
# data after enodiing process

# %% [markdown]
# we are loading the trained model which we haved saved before inorder to perform the test

# %%
import pickle

# %%
model=pickle.load(open('model_submit1.pkl','rb'))

# %%
ItemOutletSales=[]

# %%
X_test=data4.drop(['Item_Identifier'],axis=1)

# %%
X_test.head()
# Out:
#       Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  Outlet_Identifier  \
# 0          20.750                 0         13  107.8622                  9
# 3578       19.200                 0         13  178.7318                  9
# 1840        6.785                 1         13  209.1928                  9
# 4606       11.500                 0         13  125.7704                  9
# 380         5.340                 1         13   99.0358                  9
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# 3578            1                     0            1
# 1840            1                     0            1
# 4606            1                     0            1
# 380             1                     0            1

# %%
ItemOutletSales=[]

# %%
ItemOutletSales=model.predict(X_test)

# %%
#ItemOutletSales

# %%
data5=data4

# %%
data5['Item_Outlet_Sales']=ItemOutletSales

# %% [markdown]
# we haved got the prediction in the ItemOutletSales array, we are adding this array to the dataset as a new column

# %%
#data5

# %%
data5.head()
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  \
# 0              FDW58       20.750                 0         13  107.8622
# 3578           FDS10       19.200                 0         13  178.7318
# 1840           FDX22        6.785                 1         13  209.1928
# 4606           FDV21       11.500                 0         13  125.7704
# 380            FDW21        5.340                 1         13   99.0358
#
#       Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                     9            1                     0            1
# 3578                  9            1                     0            1
# 1840                  9            1                     0            1
# 4606                  9            1                     0            1
# 380                   9            1                     0            1
#
#       Item_Outlet_Sales
# 0           2071.628417
# 3578        3168.603078
# 1840        3646.626988
# 4606        2330.034085
# 380         1933.355342

# %% [markdown]
# The sample output which have been provided only requires 3 features
# 1. Item_identifier
# 2.Outlet_identifier
# 3.Item_Outlet_sales
#
# so before selecting this values from the dataframe we are making back the encoded values to normal values and we are making a new array with the following values in it

# %%
OutletId=LE.inverse_transform(data5['Outlet_Identifier'])

# %%
data5['Outlet_Identifier']=LE.inverse_transform(data5['Outlet_Identifier'])

# %%
data5.head()
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  \
# 0              FDW58       20.750                 0         13  107.8622
# 3578           FDS10       19.200                 0         13  178.7318
# 1840           FDX22        6.785                 1         13  209.1928
# 4606           FDV21       11.500                 0         13  125.7704
# 380            FDW21        5.340                 1         13   99.0358
#
#      Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0               OUT049            1                     0            1
# 3578            OUT049            1                     0            1
# 1840            OUT049            1                     0            1
# 4606            OUT049            1                     0            1
# 380             OUT049            1                     0            1
#
#       Item_Outlet_Sales
# 0           2071.628417
# 3578        3168.603078
# 1840        3646.626988
# 4606        2330.034085
# 380         1933.355342

# %%
dataout=data5[['Item_Identifier','Outlet_Identifier','Item_Outlet_Sales']]

# %%
dataout.head()
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        2071.628417
# 3578           FDS10            OUT049        3168.603078
# 1840           FDX22            OUT049        3646.626988
# 4606           FDV21            OUT049        2330.034085
# 380            FDW21            OUT049        1933.355342

# %% [markdown]
# the final formated output we require for uploading to the website

# %%
dataout.loc[dataout['Item_Outlet_Sales']<0,'Item_Outlet_Sales']=-dataout['Item_Outlet_Sales']

# %%
dataout.to_csv('output_submit1.csv')

# %% [markdown]
# the output csv file which we have created was uploaded to the virtual competition website and scores we checked
# ## the maximum score obtianed in the website is =  1265.43240000607
